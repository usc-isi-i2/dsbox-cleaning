# %%
import pandas as pd
import numpy as np

from dsbox.datapreprocessing.cleaner import Imputation
from dsbox.datapreprocessing.cleaner import encoder
from dsbox.datapreprocessing.cleaner import missing_value_pred as mvp

# PART1: get mutual information
data_path = "../dsbox-data/o_38/original/data/"
data_name = data_path + "trainData.csv"
label_name = data_path + "trainTargets.csv" # make sure your label target is in the second column of this file
data = encoder.encode(data_name)
label = encoder.text2int(pd.read_csv(label_name)["Class"])
data = data.drop("TBG_measured",axis=1)    # drop because all same value, useless
data = data.drop("d3mIndex",axis=1)    # drop because all same value, useless

from dsbox.datapreprocessing.cleaner import bayesTree

graph = bayesTree.build_complete_graph(data)

# print all
FTI_edges = graph.edges("FTI", data=True)
print sorted(FTI_edges, key=lambda x: x[2]['weight'],reverse=True)[:5]

TSH_edges = graph.edges("TSH", data=True)
print sorted(TSH_edges, key=lambda x: x[2]['weight'],reverse=True)[:5]

T4U_edges = graph.edges("T4U", data=True)
print sorted(T4U_edges, key=lambda x: x[2]['weight'],reverse=True)[:5]

T3_edges = graph.edges("T3", data=True)
print sorted(T3_edges, key=lambda x: x[2]['weight'],reverse=True)[:5]

TT4_edges = graph.edges("TT4", data=True)
print sorted(TT4_edges, key=lambda x: x[2]['weight'],reverse=True)[:5]

age_edges = graph.edges("age", data=True)
print sorted(age_edges, key=lambda x: x[2]['weight'],reverse=True)[:5]
# Out:
# ====================have a look on the data: ====================
#
#   age
# 0  55
# 1  60
# 2  53
# 3  38
# 4  45
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *sex* column: object/other category.
# ...Insert columns to onehot encode *sex*.
# ...Delete *on_thyroxine* column: object/other category.
# ...Insert columns to onehot encode *on_thyroxine*.
# ...Delete *query_on_thyroxine* column: object/other category.
# ...Insert columns to onehot encode *query_on_thyroxine*.
# ...Delete *on_antithyroid_medication* column: object/other category.
# ...Insert columns to onehot encode *on_antithyroid_medication*.
# ...Delete *sick* column: object/other category.
# ...Insert columns to onehot encode *sick*.
# ...Delete *pregnant* column: object/other category.
# ...Insert columns to onehot encode *pregnant*.
# ...Delete *thyroid_surgery* column: object/other category.
# ...Insert columns to onehot encode *thyroid_surgery*.
# ...Delete *I131_treatment* column: object/other category.
# ...Insert columns to onehot encode *I131_treatment*.
# ...Delete *query_hypothyroid* column: object/other category.
# ...Insert columns to onehot encode *query_hypothyroid*.
# ...Delete *query_hyperthyroid* column: object/other category.
# ...Insert columns to onehot encode *query_hyperthyroid*.
# ...Delete *lithium* column: object/other category.
# ...Insert columns to onehot encode *lithium*.
# ...Delete *goitre* column: object/other category.
# ...Insert columns to onehot encode *goitre*.
# ...Delete *tumor* column: object/other category.
# ...Insert columns to onehot encode *tumor*.
# ...Delete *hypopituitary* column: object/other category.
# ...Insert columns to onehot encode *hypopituitary*.
# ...Delete *psych* column: object/other category.
# ...Insert columns to onehot encode *psych*.
# ...Delete *TSH_measured* column: object/other category.
# ...Insert columns to onehot encode *TSH_measured*.
# ====================have a look on the data: ====================
#
#     TSH
# 0   0.6
# 1   0.1
# 2   0.6
# 3  0.73
# 4   NaN
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *T3_measured* column: object/other category.
# ...Insert columns to onehot encode *T3_measured*.
# ====================have a look on the data: ====================
#
#     T3
# 0  1.5
# 1  NaN
# 2  2.6
# 3  2.4
# 4  NaN
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *TT4_measured* column: object/other category.
# ...Insert columns to onehot encode *TT4_measured*.
# ====================have a look on the data: ====================
#
#      TT4
# 0  113.0
# 1  150.0
# 2  136.0
# 3  135.0
# 4    NaN
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *T4U_measured* column: object/other category.
# ...Insert columns to onehot encode *T4U_measured*.
# ====================have a look on the data: ====================
#
#     T4U
# 0  0.97
# 1  0.99
# 2  1.19
# 3  1.05
# 4   NaN
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *FTI_measured* column: object/other category.
# ...Insert columns to onehot encode *FTI_measured*.
# ====================have a look on the data: ====================
#
#      FTI
# 0  117.0
# 1  151.0
# 2  114.0
# 3  129.0
# 4    NaN
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *TBG_measured* column: object/other category.
# ...Insert columns to onehot encode *TBG_measured*.
# ...Delete *TBG* column: empty column.
# ...Delete *referral_source* column: object/other category.
# ...Insert columns to onehot encode *referral_source*.
# [('FTI', 'TT4', {'weight': 0.4900386989570928}), ('FTI', 'T3', {'weight': 0.062352420014559845}), ('FTI', 'TSH', {'weight': 0.053522740550810625}), ('FTI', 'on_thyroxine', {'weight': 0.0207703929768421}), ('FTI', 'T4U', {'weight': 0.017979979434154462})]
# [('TSH', 'FTI', {'weight': 0.053522740550810625}), ('TSH', 'TT4', {'weight': 0.0413279634516451}), ('TSH', 'T3', {'weight': 0.014908882385508523}), ('TSH', 'T4U', {'weight': 0.0033870593086019257}), ('TSH', 'age', {'weight': 0.0020636908484800375})]
# [('T4U', 'T3', {'weight': 0.11377134648766811}), ('T4U', 'TT4', {'weight': 0.09911768682232674}), ('T4U', 'pregnant', {'weight': 0.06100668647688293}), ('T4U', 'referral_source_STMW', {'weight': 0.050642389356573836}), ('T4U', 'sex_M', {'weight': 0.02852196443611737})]
# [('T3', 'TT4', {'weight': 0.18166475116614964}), ('T3', 'T4U', {'weight': 0.11377134648766811}), ('T3', 'FTI', {'weight': 0.062352420014559845}), ('T3', 'referral_source_SVI', {'weight': 0.04718133690119857}), ('T3', 'age', {'weight': 0.02716033068927026})]
# [('TT4', 'FTI', {'weight': 0.4900386989570928}), ('TT4', 'T3', {'weight': 0.18166475116614964}), ('TT4', 'T4U', {'weight': 0.09911768682232674}), ('TT4', 'TSH', {'weight': 0.0413279634516451}), ('TT4', 'on_thyroxine', {'weight': 0.025433037052822537})]
# [('age', 'referral_source_SVI', {'weight': 0.042588034890270514}), ('age', 'T3', {'weight': 0.02716033068927026}), ('age', 'referral_source_STMW', {'weight': 0.016360450212142757}), ('age', 'T4U', {'weight': 0.013441019358793004}), ('age', 'referral_source_other', {'weight': 0.008793285695114438})]

# %%
# PART2: pearson correlation
import pandas as pd
from sklearn.preprocessing import scale

pearson_correlation = data.corr("pearson")
pearson_correlation.to_csv("o38_corr.csv", index=False)

part2_result = {}
missing_col_name = ["FTI", "TSH", "T4U", "T3", "TT4", "age"]
for each in missing_col_name:
    each_result = pearson_correlation[each].abs().sort_values(ascending=False)[1:6]
    part2_result[each] = each_result.keys().tolist()

# %%
# PART3: model coeff
# maybe need to scale the data first?
data_path = "../dsbox-data_my/o_38/data/"
data_name = data_path + "trainData_scaled.csv"
label_name = data_path + "trainTargets.csv" # make sure your label target is in the second column of this file
data = encoder.encode(data_name)
label = encoder.text2int(pd.read_csv(label_name)["Class"])
data = data.drop("TBG_measured",axis=1)    # drop because all same value, useless
data = data.drop("d3mIndex",axis=1)    # drop because all same value, useless


from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import f1_score, make_scorer

clf = LogisticRegression()
scorer = make_scorer(f1_score, average="macro") # score will be * -1, if greater_is_better is set to False

imputer = Imputation(model=clf, scorer=scorer, strategy="iteratively_regre")
imputer.fit(data)
model_list = imputer.transform(data, label)
# Out:
# ====================have a look on the data: ====================
#
#                age
# 0   0.159280450632
# 1   0.404734082033
# 2  0.0610989980716
# 3  -0.675261896131
# 4   -0.33162681217
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *sex* column: object/other category.
# ...Insert columns to onehot encode *sex*.
# ...Delete *on_thyroxine* column: object/other category.
# ...Insert columns to onehot encode *on_thyroxine*.
# ...Delete *query_on_thyroxine* column: object/other category.
# ...Insert columns to onehot encode *query_on_thyroxine*.
# ...Delete *on_antithyroid_medication* column: object/other category.
# ...Insert columns to onehot encode *on_antithyroid_medication*.
# ...Delete *sick* column: object/other category.
# ...Insert columns to onehot encode *sick*.
# ...Delete *pregnant* column: object/other category.
# ...Insert columns to onehot encode *pregnant*.
# ...Delete *thyroid_surgery* column: object/other category.
# ...Insert columns to onehot encode *thyroid_surgery*.
# ...Delete *I131_treatment* column: object/other category.
# ...Insert columns to onehot encode *I131_treatment*.
# ...Delete *query_hypothyroid* column: object/other category.
# ...Insert columns to onehot encode *query_hypothyroid*.
# ...Delete *query_hyperthyroid* column: object/other category.
# ...Insert columns to onehot encode *query_hyperthyroid*.
# ...Delete *lithium* column: object/other category.
# ...Insert columns to onehot encode *lithium*.
# ...Delete *goitre* column: object/other category.
# ...Insert columns to onehot encode *goitre*.
# ...Delete *tumor* column: object/other category.
# ...Insert columns to onehot encode *tumor*.
# ...Delete *hypopituitary* column: object/other category.
# ...Insert columns to onehot encode *hypopituitary*.
# ...Delete *psych* column: object/other category.
# ...Insert columns to onehot encode *psych*.
# ...Delete *TSH_measured* column: object/other category.
# ...Insert columns to onehot encode *TSH_measured*.
# ====================have a look on the data: ====================
#
#                TSH
# 0  -0.182269941573
# 1  -0.200933847977
# 2  -0.182269941573
# 3  -0.177417325907
# 4              NaN
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *T3_measured* column: object/other category.
# ...Insert columns to onehot encode *T3_measured*.
# ====================have a look on the data: ====================
#
#                 T3
# 0  -0.621861205037
# 1              NaN
# 2    0.71430710466
# 3   0.471367411988
# 4              NaN
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *TT4_measured* column: object/other category.
# ...Insert columns to onehot encode *TT4_measured*.
# ====================have a look on the data: ====================
#
#               TT4
# 0  0.133131453437
# 1    1.1704096886
# 2  0.777926032054
# 3  0.749891485157
# 4             NaN
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *T4U_measured* column: object/other category.
# ...Insert columns to onehot encode *T4U_measured*.
# ====================have a look on the data: ====================
#
#                 T4U
# 0    -0.12950244821
# 1  -0.0282093109286
# 2    0.984722061883
# 3    0.275670100915
# 4               NaN
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *FTI_measured* column: object/other category.
# ...Insert columns to onehot encode *FTI_measured*.
# ====================have a look on the data: ====================
#
#               FTI
# 0  0.191324332826
# 1   1.20604576728
# 2  0.101790088609
# 3  0.549461309693
# 4             NaN
# ====================calculating the features ... ====================
#
# ====================calculations finished ====================
#
# ...Delete *TBG_measured* column: object/other category.
# ...Insert columns to onehot encode *TBG_measured*.
# ...Delete *TBG* column: empty column.
# ...Delete *referral_source* column: object/other category.
# ...Insert columns to onehot encode *referral_source*.
# =========> iteratively regress method:
# =========> iteratively regress method:
# missing column name: ['age', 'TSH', 'T3', 'TT4', 'T4U', 'FTI']
# number of imputated cells: 1
# score is: 0.856689139491
# ===========>> max score is: 0.856689139491
# number of imputated cells: 295
# score is: 0.856689139491
# ===========>> max score is: 0.856689139491
# number of imputated cells: 604
# score is: 0.856689139491
# ===========>> max score is: 0.856689139491
# number of imputated cells: 184
# score is: 0.856689139491
# ===========>> max score is: 0.856689139491
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.855755452953
# ===========>> max score is: 0.855755452953
# number of imputated cells: 1
# score is: 0.855755452953
# ===========>> max score is: 0.855755452953
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.855755452953
# ===========>> max score is: 0.855755452953
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 9.70496125723
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 4.75451897524
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 3.69732627652
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 2.87007278917
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 2.22837061665
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 1.73112687006
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 1.34602000796
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 1.04790114648
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.817215779595
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.63876619342
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.50074756983
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.393996834975
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.311407044274
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.247470765335
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.197924083244
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.159469136398
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.129557953904
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.106224143201
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.0879519194874
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.0735742654014
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.0621938043024
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.0531213739778
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.0458283854998
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.0399099106447
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.03505611291
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.0310301622028
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.0276511836163
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.0247811111999
# number of imputated cells: 1
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 295
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 604
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 184
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 326
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# number of imputated cells: 324
# score is: 0.852798882884
# ===========>> max score is: 0.852798882884
# changed distance: 0.0223145678824

# %%
part3_result = {}
FTI_coef = pd.Series(abs(model_list[5].coef_),data.keys().delete(5))
part3_result["FTI"] = FTI_coef.sort_values(ascending=False)[:5].keys().tolist()
print "for FTI: "
print FTI_coef.sort_values(ascending=False)

TSH_coef = pd.Series(abs(model_list[1].coef_),data.keys().delete(1))
part3_result["TSH"] = TSH_coef.sort_values(ascending=False)[:5].keys().tolist()
print "\n for TSH: "
print TSH_coef.sort_values(ascending=False)

T4U_coef = pd.Series(abs(model_list[4].coef_),data.keys().delete(4))
part3_result["T4U"] = T4U_coef.sort_values(ascending=False)[:5].keys().tolist()
print "\n for T4U: "
print T4U_coef.sort_values(ascending=False)

T3_coef = pd.Series(abs(model_list[2].coef_),data.keys().delete(2))
part3_result["T3"] = T3_coef.sort_values(ascending=False)[:5].keys().tolist()
print "\n for T3: "
print T3_coef.sort_values(ascending=False)

TT4_coef = pd.Series(abs(model_list[3].coef_),data.keys().delete(3))
part3_result["TT4"] = TT4_coef.sort_values(ascending=False)[:5].keys().tolist()
print "\n for TT4: "
print TT4_coef.sort_values(ascending=False)

age_coef = pd.Series(abs(model_list[0].coef_),data.keys().delete(0))
part3_result["age"] = age_coef.sort_values(ascending=False)[:5].keys().tolist()
print "\n for age: "
print age_coef.sort_values(ascending=False)
# Out:
# for FTI:
# TT4                          1.049228e+00
# T4U                          6.638677e-01
# thyroid_surgery              8.943646e-02
# pregnant                     8.132638e-02
# goitre                       7.648768e-02
# T4U_measured                 6.646395e-02
# query_on_thyroxine           5.752893e-02
# hypopituitary                5.711577e-02
# on_antithyroid_medication    5.105791e-02
# query_hyperthyroid           4.662365e-02
# referral_source_SVHD         4.478406e-02
# T3                           4.471972e-02
# TSH                          3.609021e-02
# TSH_measured                 3.235858e-02
# lithium                      3.148159e-02
# referral_source_STMW         2.909035e-02
# on_thyroxine                 2.266810e-02
# TT4_measured                 2.078907e-02
# query_hypothyroid            1.409673e-02
# sick                         1.280781e-02
# sex_M                        1.208386e-02
# referral_source_SVI          1.077568e-02
# tumor                        9.705568e-03
# sex_nan                      8.974603e-03
# age                          8.188263e-03
# referral_source_other        7.779862e-03
# T3_measured                  3.787096e-03
# sex_F                        3.109260e-03
# referral_source_SVHC         2.861837e-03
# psych                        2.685251e-03
# I131_treatment               1.875050e-03
# FTI_measured                 8.526262e-16
# dtype: float64
#
#  for TSH:
# TT4                          9.754293e-01
# T4U                          6.644051e-01
# FTI                          6.048041e-01
# pregnant                     3.255806e-01
# goitre                       2.726799e-01
# on_thyroxine                 2.078385e-01
# on_antithyroid_medication    1.785282e-01
# T3                           1.559060e-01
# referral_source_SVHC         1.227546e-01
# sick                         1.214755e-01
# referral_source_STMW         1.201342e-01
# I131_treatment               1.166374e-01
# query_on_thyroxine           1.086485e-01
# hypopituitary                8.938648e-02
# query_hyperthyroid           8.621736e-02
# thyroid_surgery              8.111762e-02
# TT4_measured                 6.342518e-02
# age                          6.216128e-02
# referral_source_other        5.709353e-02
# FTI_measured                 5.584087e-02
# sex_nan                      5.382197e-02
# lithium                      4.653913e-02
# sex_M                        4.302506e-02
# tumor                        4.288206e-02
# T3_measured                  4.130222e-02
# referral_source_SVI          3.808500e-02
# psych                        2.996826e-02
# T4U_measured                 1.641561e-02
# referral_source_SVHD         1.638813e-02
# sex_F                        1.079690e-02
# query_hypothyroid            8.245857e-03
# TSH_measured                 1.083740e-16
# dtype: float64
#
#  for T4U:
# TT4                          1.410635e+00
# FTI                          1.314037e+00
# pregnant                     3.053219e-01
# hypopituitary                1.848388e-01
# thyroid_surgery              1.666532e-01
# goitre                       1.625801e-01
# referral_source_STMW         1.038995e-01
# T3                           9.474480e-02
# query_on_thyroxine           8.427214e-02
# TT4_measured                 8.331982e-02
# TSH                          7.239637e-02
# TSH_measured                 5.434932e-02
# referral_source_SVHD         5.060512e-02
# on_thyroxine                 4.943040e-02
# lithium                      4.423181e-02
# on_antithyroid_medication    4.274336e-02
# query_hyperthyroid           3.840963e-02
# sex_M                        3.073814e-02
# sex_F                        2.935645e-02
# tumor                        2.473124e-02
# referral_source_SVHC         2.227110e-02
# sick                         1.824018e-02
# referral_source_SVI          1.800709e-02
# I131_treatment               1.519079e-02
# referral_source_other        1.301617e-02
# age                          7.783883e-03
# psych                        6.255230e-03
# query_hypothyroid            5.779411e-03
# T3_measured                  2.945452e-03
# sex_nan                      1.381693e-03
# FTI_measured                 1.308502e-15
# T4U_measured                 3.268906e-16
# dtype: float64
#
#  for T3:
# T4U                          5.352032e-01
# FTI                          4.705679e-01
# tumor                        3.922216e-01
# referral_source_SVI          2.947616e-01
# on_thyroxine                 2.754079e-01
# thyroid_surgery              2.144396e-01
# query_hyperthyroid           2.045225e-01
# TT4_measured                 1.918010e-01
# sick                         1.874637e-01
# on_antithyroid_medication    1.749977e-01
# referral_source_STMW         1.732068e-01
# TSH_measured                 1.669905e-01
# query_on_thyroxine           1.649341e-01
# query_hypothyroid            1.224643e-01
# age                          1.200074e-01
# T4U_measured                 1.160236e-01
# sex_M                        1.097228e-01
# TSH                          8.996713e-02
# psych                        8.066153e-02
# TT4                          8.060142e-02
# FTI_measured                 7.241643e-02
# I131_treatment               6.846029e-02
# referral_source_SVHC         6.763098e-02
# referral_source_other        5.704635e-02
# sex_nan                      5.619531e-02
# sex_F                        5.352749e-02
# pregnant                     4.039300e-02
# hypopituitary                2.595065e-02
# lithium                      1.562252e-02
# goitre                       1.355669e-02
# referral_source_SVHD         3.122482e-03
# T3_measured                  1.329574e-16
# dtype: float64
#
#  for TT4:
# FTI                          8.952099e-01
# T4U                          6.081008e-01
# hypopituitary                9.087417e-02
# thyroid_surgery              9.086433e-02
# goitre                       8.887183e-02
# T4U_measured                 8.095857e-02
# pregnant                     7.086963e-02
# on_thyroxine                 5.920892e-02
# TSH                          4.614620e-02
# query_on_thyroxine           4.473764e-02
# referral_source_SVHD         3.942271e-02
# query_hyperthyroid           3.129003e-02
# on_antithyroid_medication    2.876991e-02
# TSH_measured                 2.448041e-02
# FTI_measured                 1.767763e-02
# tumor                        1.746274e-02
# lithium                      1.706881e-02
# referral_source_STMW         1.699757e-02
# I131_treatment               1.465560e-02
# sick                         1.237517e-02
# T3                           1.162208e-02
# referral_source_other        1.115815e-02
# query_hypothyroid            1.099439e-02
# psych                        8.520134e-03
# referral_source_SVI          5.785261e-03
# referral_source_SVHC         5.481717e-03
# sex_M                        3.877533e-03
# sex_nan                      3.395077e-03
# age                          2.735606e-03
# T3_measured                  2.460816e-03
# sex_F                        4.824562e-04
# TT4_measured                 7.449345e-16
# dtype: float64
#
#  for age:
# referral_source_STMW         0.593692
# referral_source_SVI          0.469201
# I131_treatment               0.369381
# goitre                       0.292766
# on_antithyroid_medication    0.259454
# thyroid_surgery              0.256648
# T3                           0.231077
# pregnant                     0.221927
# referral_source_SVHD         0.216345
# FTI                          0.152081
# T4U_measured                 0.143680
# referral_source_SVHC         0.142216
# query_on_thyroxine           0.131299
# lithium                      0.129013
# psych                        0.126998
# TSH_measured                 0.125292
# hypopituitary                0.103025
# TT4_measured                 0.096487
# sick                         0.086911
# query_hypothyroid            0.082823
# TSH                          0.068517
# sex_F                        0.064808
# tumor                        0.063051
# FTI_measured                 0.060225
# T4U                          0.054248
# sex_nan                      0.052581
# referral_source_other        0.050363
# query_hyperthyroid           0.041350
# T3_measured                  0.032719
# TT4                          0.028141
# sex_M                        0.012227
# on_thyroxine                 0.009131
# dtype: float64

# %%
# part2_result -> top 5 attributes using mutual information (or say: pearson correlation)

# part3_result -> top 5 attributes using regression model coefficient

print part2_result
print "\n"
print part3_result
print "\n"

# lets see what the intersection looks like
for each in missing_col_name:
    intersection = [filter(lambda x: x in part2_result[each], part3_result[each])]
    print "{}: {}".format(each, intersection)
    
# as can see from the result, they for top5, usually have 2~3 number of intersected elements.
# Out:
# {'TSH': ['FTI', 'TT4', 'T3', 'T4U', 'age'], 'age': ['referral_source_SVI', 'T3', 'referral_source_STMW', 'T4U', 'referral_source_other'], 'T3': ['TT4', 'T4U', 'FTI', 'referral_source_SVI', 'age'], 'T4U': ['T3', 'TT4', 'pregnant', 'referral_source_STMW', 'sex_M'], 'TT4': ['FTI', 'T3', 'T4U', 'TSH', 'on_thyroxine'], 'FTI': ['TT4', 'T3', 'TSH', 'on_thyroxine', 'T4U']}
#
#
# {'TSH': ['TT4', 'T4U', 'FTI', 'pregnant', 'goitre'], 'age': ['referral_source_STMW', 'referral_source_SVI', 'I131_treatment', 'goitre', 'on_antithyroid_medication'], 'T3': ['T4U', 'FTI', 'tumor', 'referral_source_SVI', 'on_thyroxine'], 'T4U': ['TT4', 'FTI', 'pregnant', 'hypopituitary', 'thyroid_surgery'], 'TT4': ['FTI', 'T4U', 'hypopituitary', 'thyroid_surgery', 'goitre'], 'FTI': ['TT4', 'T4U', 'thyroid_surgery', 'pregnant', 'goitre']}
#
#
# FTI: [['TT4', 'T4U']]
# TSH: [['TT4', 'T4U', 'FTI']]
# T4U: [['TT4', 'pregnant']]
# T3: [['T4U', 'FTI', 'referral_source_SVI']]
# TT4: [['FTI', 'T4U']]
# age: [['referral_source_STMW', 'referral_source_SVI']]
